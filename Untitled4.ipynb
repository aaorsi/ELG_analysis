# %%
import jplus

gal_sdss_coords_faint  = jplus.datasets.fetch_custom_sdss(mag_type="aperMags",overwrite=False,mag_limit=[21, 22], extinction=False,
                                                          clean = True, nchunks = 15, spectroscopic=False, 
                                                    casjobs=True, object_name="photgalaxies",
                                                    runname='coords_faint', get_coords=True)
# Out:
# j-plus [INFO]: Fetching SDSS galaxies
# j-plus [INFO]: Monitoring job: 37366840 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 37366840 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 37366840 - Status: 5, finished
# j-plus [INFO]: SELECT
#    p.objid
#     , p.ra, p.dec
#
#
#
# INTO mydb.MyTable
# FROM
#    dr14.photoobj AS p
# WHERE
#    p.r BETWEEN 21 AND 22
#    AND p.type = 3 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) >= 0.0 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) < 0.0666666666667 AND p.clean = 1 AND (p.calibStatus_r & 1) != 0
#    ORDER BY p.objid
# j-plus [INFO]: Monitoring job: 37366842 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 37366842 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 37366842 - Status: 1, started
# j-plus [INFO]: Monitoring job: 37366842 - Status: 1, started
# j-plus [INFO]: Monitoring job: 37366842 - Status: 1, started
# j-plus [INFO]: Monitoring job: 37366842 - Status: 1, started
# j-plus [INFO]: Monitoring job: 37366842 - Status: 1, started
# ...
