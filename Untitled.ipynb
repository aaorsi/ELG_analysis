# %%
import jplus
gal_sdss  = jplus.datasets.fetch_sdss_photgalaxies(mag_type="none",overwrite=True,mag_limit=[16,20],
                                                           extinction=False, 
                                                           nchunks=10)
# Out:
# j-plus [INFO]: Fetching SDSS galaxies
# j-plus [INFO]: Monitoring job: 36652541 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36652541 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36652541 - Status: 5, finished
# j-plus [INFO]: SELECT
#    p.objid, p.ra, p.dec
#
#
# INTO mydb.MyTable
# FROM
#    dr14.photoobj AS p
# WHERE
#    p.r BETWEEN 16 AND 20
#    AND p.type = 3 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) >= 0.0 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) < 0.1
# j-plus [INFO]: Monitoring job: 36652545 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36652545 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36652545 - Status: 1, started
# ...

# %%
gal_sdss  = jplus.datasets.fetch_sdss_photgalaxies(mag_type="aperMags",overwrite=True,mag_limit=[16,20],
                                                           extinction=False, 
                                                           nchunks=70)
# Out:
# j-plus [INFO]: Fetching SDSS galaxies
# j-plus [INFO]: Monitoring job: 36653383 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36653383 - Status: 4, failed
# j-plus [WARNING]: Couldn't drop table MyTable
# j-plus [INFO]: SELECT
#    p.objid, p.ra, p.dec
#    , p.fiberMag_u as u, p.fiberMag_g as g, p.fiberMag_r as r, p.fiberMag_i as i, p.fiberMag_z as z,
#    p.fiberMagErr_u as u_err, p.fiberMagErr_g as g_err, p.fiberMagErr_r as r_err, p.fiberMagErr_i as i_err, p.fiberMagErr_z as z_err,
# INTO mydb.MyTable
# FROM
#    dr14.photoobj AS p
# WHERE
#    p.r BETWEEN 16 AND 20
#    AND p.type = 3 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) >= 0.0 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) < 0.0142857142857
# j-plus [INFO]: Monitoring job: 36653384 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36653384 - Status: 4, failed
# j-plus [INFO]:     Request and get output
# j-plus [INFO]: Monitoring job: 36653385 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36653385 - Status: 0, ready
# ...
