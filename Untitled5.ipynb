# %%
import jplus
gal_sdss_ugz_err = jplus.datasets.fetch_custom_sdss(mag_type="aperMags",overwrite=True,mag_limit=[16,21], extinction=False,
                                                          clean = True, nchunks = 10, spectroscopic=False, 
                                                    casjobs=True, object_name="photgalaxies",get_u_err=True, get_g_err=True, get_z_err=True,
                                                    runname='ugz_err', get_coords=False)
# Out:
# j-plus [INFO]: Fetching SDSS galaxies
# j-plus [INFO]: Monitoring job: 36870616 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36870616 - Status: 5, finished
# j-plus [INFO]: SELECT
#    p.objid
#
#
#     , p.fiberMagErr_u as u_err, p.fiberMagErr_g as g_err, p.fiberMagErr_z as z_err
#
# INTO mydb.MyTable
# FROM
#    dr14.photoobj AS p
# WHERE
#    p.r BETWEEN 16 AND 21
#    AND p.type = 3 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) >= 0.0 AND (ABS(p.ra) - FLOOR(ABS(p.ra))) < 0.1 AND p.clean = 1 AND (p.calibStatus_r & 1) != 0
#    ORDER BY p.objid
# j-plus [INFO]: Monitoring job: 36870617 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36870617 - Status: 0, ready
# j-plus [INFO]: Monitoring job: 36870617 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36870617 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36870617 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36870617 - Status: 1, started
# j-plus [INFO]: Monitoring job: 36870617 - Status: 1, started
# ...
