# %%
import jplus
gal_psfworst = jplus.datasets.fetch_jplus_objects(mag_type="wpsfMags", overwrite=False, 
                                                 object_name="allELGs", nchunks=20, 
                                                 mag_limit=[16,24],
                                                  extra_where_conds='',db='upad')
# Out:
# j-plus [INFO]: Fetching J-PLUS galaxies
# j-plus [INFO]:    Connecting to the upad database
# j-plus [INFO]: SELECT m.alpha_j2000 as ra, m.delta_j2000 as dec, t.DATASUM as datasum,
#    m.FWHM_WORLD*3600 as fwhm, m.CLASS_STAR as cstar, m.tile_id as tile_id, m.number as object_id,
#    m.KRON_RADIUS as kron_rad, m.PETRO_RADIUS as petro_rad, m.MU_MAX[jplus::rSDSS] as mu_max_r,
#    m.mag_aper3_worstpsf[jplus::uJAVA] as uJAVA, m.mag_err_aper3_worstpsf[jplus::uJAVA] as uJAVA_err,
#    m.mag_aper3_worstpsf[jplus::gSDSS] as gJAVA, m.mag_err_aper3_worstpsf[jplus::gSDSS] as gJAVA_err,
#    m.mag_aper3_worstpsf[jplus::rSDSS] as rJAVA, m.mag_err_aper3_worstpsf[jplus::rSDSS] as rJAVA_err,
#    m.mag_aper3_worstpsf[jplus::iSDSS] as iJAVA, m.mag_err_aper3_worstpsf[jplus::iSDSS] as iJAVA_err,
#    m.mag_aper3_worstpsf[jplus::zSDSS] as zJAVA, m.mag_err_aper3_worstpsf[jplus::zSDSS] as zJAVA_err,
#    m.mag_aper3_worstpsf[jplus::J0378] as J0378, m.mag_err_aper3_worstpsf[jplus::J0378] as J0378_err,
# ...
